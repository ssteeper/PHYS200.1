# %%
a = rand[100]
# Out:
# <span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">/home/ssteeper/PHYS200.1/&lt;ipython-input-1-a94cb2735955&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>a <span class="ansiyellow">=</span> rand<span class="ansiyellow">[</span><span class="ansicyan">100</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
#
# <span class="ansired">TypeError</span>: &apos;builtin_function_or_method&apos; object is not subscriptable

# %%
a = rand(100)

# %%
plot a
# Out:
# <span class="ansicyan">  File </span><span class="ansigreen">&quot;&lt;ipython-input-3-88f71a8ccf81&gt;&quot;</span><span class="ansicyan">, line </span><span class="ansigreen">1</span>
# <span class="ansiyellow">    plot a</span>
# <span class="ansigrey">         ^</span>
# <span class="ansired">SyntaxError</span><span class="ansired">:</span> invalid syntax

# %%
plot(a)
# Out:
# [&lt;matplotlib.lines.Line2D at 0xaaee36c&gt;]
